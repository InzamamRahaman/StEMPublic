# %%
# %load_ext autoreload
# %autoreload 2

# %pylab inline

import dataloaders
import models
import sklearn.linear_model as linear_model
import sklearn.metrics as metrics 
import sklearn.cluster as cluster
import numpy as np 
import random
import classifiers
from torch.autograd import Variable
import torch
import torch.nn as nn 
import torch.optim as optim

from imblearn.under_sampling import RandomUnderSampler
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
output_file_vot = '../data/senate-104-cleaned.csv'
output_file_nam = '../data/senate-104-classes.csv'
data = dataloaders.SenateDataset(output_file_vot, output_file_nam, ratio=0.8, delimiter=',')

# %%
num_nodes = data.get_num_nodes()
dims = 32
epochs = 200
lr = 0.1
lr_decay=0.0
weight_decay=0.0
lam = 0.00055
X_train, y_train = data.get_training_set()
X_test, y_test = data.get_testing_set()
p = 2
X = data.X
y = data.y

model_fitter = models.fit_pseudo_kernel_model

# %%
kernel_model = model_fitter(num_nodes, dims, X, y, epochs=epochs, p=p, 
                                              lr=lr,lr_decay=lr_decay, lam=lam, weight_decay=weight_decay, undersample=True)
# Out:
# The loss at epoch  1  was  0.706278383731842
# The loss at epoch  2  was  0.694980800151825
# The loss at epoch  3  was  0.6958025693893433
# The loss at epoch  4  was  0.7013280391693115
# The loss at epoch  5  was  0.6870283484458923
# The loss at epoch  6  was  0.6376263499259949
# The loss at epoch  7  was  0.5814656615257263
# The loss at epoch  8  was  0.5794428586959839
# The loss at epoch  9  was  0.5760853886604309
# The loss at epoch  10  was  0.5734357237815857
# The loss at epoch  11  was  0.5721161365509033
# The loss at epoch  12  was  0.5710029006004333
# The loss at epoch  13  was  0.5697830319404602
# The loss at epoch  14  was  0.5690896511077881
# The loss at epoch  15  was  0.5679240226745605
# The loss at epoch  16  was  0.5676043629646301
# The loss at epoch  17  was  0.5667226314544678
# The loss at epoch  18  was  0.5660707950592041
# The loss at epoch  19  was  0.5654016733169556
# The loss at epoch  20  was  0.5649967789649963
# The loss at epoch  21  was  0.5644101500511169
# The loss at epoch  22  was  0.5639758706092834
# The loss at epoch  23  was  0.5634849071502686
# The loss at epoch  24  was  0.5629236102104187
# The loss at epoch  25  was  0.5626382827758789
# The loss at epoch  26  was  0.5622305274009705
# The loss at epoch  27  was  0.5618736743927002
# The loss at epoch  28  was  0.5614144802093506
# The loss at epoch  29  was  0.5612485408782959
# The loss at epoch  30  was  0.5610317587852478
# The loss at epoch  31  was  0.5606695413589478
# The loss at epoch  32  was  0.5605589151382446
# The loss at epoch  33  was  0.5600647330284119
# The loss at epoch  34  was  0.55992192029953
# The loss at epoch  35  was  0.5595774054527283
# The loss at epoch  36  was  0.5595027804374695
# The loss at epoch  37  was  0.5591916441917419
# The loss at epoch  38  was  0.5590391159057617
# The loss at epoch  39  was  0.5589282512664795
# The loss at epoch  40  was  0.5586792826652527
# The loss at epoch  41  was  0.5586264133453369
# The loss at epoch  42  was  0.5583553314208984
# The loss at epoch  43  was  0.5584405660629272
# The loss at epoch  44  was  0.5579842329025269
# The loss at epoch  45  was  0.5578380227088928
# The loss at epoch  46  was  0.5579211115837097
# The loss at epoch  47  was  0.5576212406158447
# The loss at epoch  48  was  0.557526707649231
# The loss at epoch  49  was  0.5572888851165771
# The loss at epoch  50  was  0.5572484135627747
# The loss at epoch  51  was  0.5571483969688416
# The loss at epoch  200  was  0.34131720662117004

# %%
import community

# %%
m = kernel_model

# %%
clusterer, cluster_labels = community.cluster_from_model(m, min_cluster_size=10)

# %%
len(cluster_labels[cluster_labels == -1])
# Out:
# 4

# %%
len(cluster_labels[cluster_labels == 0])
# Out:
# 47

# %%
len(cluster_labels[cluster_labels == 1])
# Out:
# 16

# %%
max(cluster_labels)
# Out:
# 3

# %%
len(y)
# Out:
# 10506

# %%
for i in range(-1, max(cluster_labels) + 1):
    print(i, ' : ', len(cluster_labels[cluster_labels == i]))
# Out:
# -1  :  4
# 0  :  47
# 1  :  16
# 2  :  19
# 3  :  17

# %%
from sklearn.manifold import TSNE, MDS

# %%
tsne = TSNE(n_components=2)

# %%
vecs = kernel_model.get_all_weights()[1:]

# %%
transformed_vecs = tsne.fit_transform(vecs)

# %%
import seaborn as sns
import pandas as pd

sns.set_style("darkgrid")
from pylab import rcParams
rcParams['figure.figsize'] = 20, 20
rcParams['axes.titlesize'] = 14
colors = ['blue' if x == 0 else 'red' for x in data.get_node_classes()]
labels = ['Democrat' if x == 0 else 'Republican' for x in data.get_node_classes()]
fig, ax = plt.subplots()
label_dict = {0: 'Democrat', 1: 'Republic'}
color_dict = {0: 'blue', 1: 'red'}
xs = set(x for x in data.get_node_classes())
classes = np.array(data.get_node_classes())
for x in xs:
    ids = np.array(range(len(classes)))[classes == x]
    ax.scatter(x=transformed_vecs[ids,0], y=transformed_vecs[ids, 1], label=label_dict[x], c=color_dict[x])

#ax.set_title('$\mathbb{R}^2$ Projection of Senate Dataset')

font_dict = fontdict={'fontsize': 20,
 'fontweight' : rcParams['axes.titleweight'],
 'verticalalignment': 'baseline'}

ax.set_xlabel('component1', fontdict=font_dict)
ax.set_ylabel('component2', fontdict=font_dict)
ax.legend(prop={'size': font_dict['fontsize']})
ax.grid(True)
fig.savefig('SenateProjection.png')

# %%
arr = plt.subplot(211)

# %%
arr

# %%
plt.scatter(transformed_vecs[:,0], transformed_vecs[:,1])

# %%
fig, ax = plt.subplots()
ax.scatter(transformed_vecs[:,0], transformed_vecs[:,1], c=colors, label=labels)
ax.legend()
ax.grid(True)
plt.show()

# %%
import matplotlib.lines as lines

# %%
blue_lines = lines.Line2D([],[], color='blue', label='Democrat', marker='.')
red_lines = lines.Line2D([],[], color='red', label='Republican', marker='.')

# %%
plt.legend([blue_lines, red_lines])

# %%
plt.scatter(transformed_vecs[:,0], transformed_vecs[:,1], c=colors)

# %%
plt.scatter(transformed_vecs[:,0], transformed_vecs[:,1], c=colors)

# %%
not_noise = np.array(range(len(cluster_labels)))[cluster_labels != -1]

# %%
not_noise_vecs = transformed_vecs[not_noise, :]

# %%
not_noise_labels = cluster_labels[not_noise]

# %%
len(not_noise_vecs)
# Out:
# 0

# %%
plt.scatter(not_noise_vecs[:,0], not_noise_vecs[:,1])

# %%
zero_cluster = np.array(range(len(cluster_labels)))[cluster_labels == 0]

# %%
zero_cluster
# Out:
# array([1096, 2607, 2608, 2708, 2805, 3165, 3270, 3567, 3898, 4469, 4884,
#        5138, 5469])

# %%
for x in zero_cluster:
    for y in zero_cluster:
        if x != y:
            inpt_x = Variable(torch.LongTensor([int(x) + 1]))
            inpt_y = Variable(torch.LongTensor([int(y) + 1]))
            #print(inpt_x)
            print(kernel_model(inpt_x, inpt_y))
# Out:
# Variable containing:
#  0.9776  0.0224
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9943  0.0057
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9992  0.0008
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9994  0.0006
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9972  0.0028
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9989  0.0011
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9974  0.0026
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9958  0.0042
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9871  0.0129
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9998  0.0002
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9992  0.0008
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9992  0.0008
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9957  0.0043
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9998  0.0002
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9990  0.0010
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9996  0.0004
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9996  0.0004
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9993  0.0007
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9977  0.0023
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  1.0000  0.0000
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9992  0.0008
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9995  0.0005
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  1.0000  0.0000
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  1.0000  0.0000
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9998  0.0002
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9998  0.0002
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9996  0.0004
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9989  0.0011
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  9.9999e-01  7.7584e-06
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9999  0.0001
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  1.0000  0.0000
# [torch.FloatTensor of size 1x2]
#
# Variable containing:
#  0.9996  0.0004
# [torch.FloatTensor of size 1x2]

# %%
clf = linear_model.LogisticRegression()
reports = classifiers.train_and_evaluate_classifier(clf, kernel_model, X_train, y_train, X_test, y_test,
                                                    operation='average', undersample=True, ratio=2)
# Out:
# Assembling training set features....
# Fitting classifier model
# Assembling testing set features

# %%
reports
# Out:
# {'auc': 0.87966080546537984,
#  'average_percision_score': 0.98338787909043979,
#  'classification_report': '             precision    recall  f1-score   support\n\n          0       0.39      0.61      0.48       723\n          1       0.95      0.89      0.92      6396\n\navg / total       0.90      0.86      0.88      7119\n',
#  'confusion_matrix': array([[ 443,  280],
#         [ 687, 5709]]),
#  'macro_f1': 0.70003261522466498,
#  'micro_f1': 0.86416631549374912}

# %%
mds = MDS(n_components=2, max_iter=100, n_init=1)
mds_transformed_vecs = mds.fit_transform(vecs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-9f8032bdaa11> in <module>()
#       1 mds = MDS(n_components=2, max_iter=100, n_init=1)
# ----> 2 mds_transformed_vecs = mds.fit_transform(vecs)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py in fit_transform(self, X, y, init)
#     427             n_jobs=self.n_jobs, max_iter=self.max_iter, verbose=self.verbose,
#     428             eps=self.eps, random_state=self.random_state,
# --> 429             return_n_iter=True)
#     430
#     431         return self.embedding_
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter)
#     252                 n_components=n_components, init=init,
#     253                 max_iter=max_iter, verbose=verbose,
# --> 254                 eps=eps, random_state=random_state)
#     255             if best_stress is None or stress < best_stress:
#     256                 best_stress = stress
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py in _smacof_single(dissimilarities, metric, n_components, init, max_iter, verbose, eps, random_state)
#      68         The number of iterations corresponding to the best stress.
#      69     """
# ---> 70     dissimilarities = check_symmetric(dissimilarities, raise_exception=True)
#      71
#      72     n_samples = dissimilarities.shape[0]
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_symmetric(array, tol, raise_warning, raise_exception)
#     705     if not symmetric:
#     706         if raise_exception:
# --> 707             raise ValueError("Array must be symmetric")
#     708         if raise_warning:
#     709             warnings.warn("Array is not symmetric, and will be converted "
#
# ValueError: Array must be symmetric

# %%
mds_transformed_vecs
# Out:
# array([[ -7.60696952e+00,   2.04837034e+00],
#        [  7.29039426e+00,   2.18655412e+00],
#        [ -1.73645750e+00,   7.72647508e-01],
#        ...,
#        [  1.80892698e-01,   1.70493662e-01],
#        [ -1.34571525e-01,  -2.98967273e-02],
#        [ -9.84608925e-02,   1.92789839e-03]])

# %%
plt.scatter(mds_transformed_vecs[not_noise,0], mds_transformed_vecs[not_noise,1], c=not_noise_labels)
