# %%
# %load_ext autoreload
# %autoreload 2

# %pylab inline

import dataloaders
import models
import sklearn.linear_model as linear_model
import sklearn.metrics as metrics 
import sklearn.cluster as cluster
import numpy as np 
import random
import classifiers
from torch.autograd import Variable
import torch
import torch.nn as nn 
import torch.optim as optim
import util

from imblearn.under_sampling import RandomUnderSampler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
# /Users/inzamamrahaman/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['random', 'colors', 'clf']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
output_file_vot = '../data/pollblogs/pollblogs-cleaned.csv'
output_file_nam = '../data/pollblogs/pollblogs-class.csv'
data = dataloaders.SenateDataset(output_file_vot, output_file_nam, ratio=0.8, delimiter=',')

# %%
num_nodes = data.get_num_nodes()
dims = 16
epochs = 200
lr = 0.10
lr_decay=0.0
weight_decay=0.0
lam = 0.00055
X_train, y_train = data.get_training_set()
X_test, y_test = data.get_testing_set()
p = 2
X = data.X
y = data.y

model_fitter = models.fit_pseudo_kernel_model

# %%
len(y)
# Out:
# 19090

# %%
kernel_model = model_fitter(num_nodes, dims, X, y, epochs=epochs, p=p, 
                                              lr=lr,lr_decay=lr_decay, lam=lam, 
                            weight_decay=weight_decay, undersample=False)
# Out:
# The loss at epoch  1  was  0.6944937109947205
# The loss at epoch  2  was  0.6849327683448792
# The loss at epoch  3  was  0.6652415990829468
# The loss at epoch  4  was  0.626087486743927
# The loss at epoch  5  was  0.5616983771324158
# The loss at epoch  6  was  0.5563313364982605
# The loss at epoch  7  was  0.5559967756271362
# The loss at epoch  8  was  0.5538985133171082
# The loss at epoch  9  was  0.5527697205543518
# The loss at epoch  10  was  0.5521761178970337
# The loss at epoch  11  was  0.5515984296798706
# The loss at epoch  12  was  0.5514703392982483
# The loss at epoch  13  was  0.5508777499198914
# The loss at epoch  14  was  0.5510369539260864
# The loss at epoch  15  was  0.5500971078872681
# The loss at epoch  16  was  0.5500203371047974
# The loss at epoch  17  was  0.5490973591804504
# The loss at epoch  18  was  0.54908686876297
# The loss at epoch  19  was  0.5473095774650574
# The loss at epoch  20  was  0.5469959378242493
# The loss at epoch  21  was  0.5451579689979553
# The loss at epoch  22  was  0.5455335378646851
# The loss at epoch  23  was  0.5445321202278137
# The loss at epoch  24  was  0.5448381304740906
# The loss at epoch  25  was  0.5436190366744995
# The loss at epoch  26  was  0.5439639687538147
# The loss at epoch  27  was  0.5430958271026611
# The loss at epoch  28  was  0.5437657237052917
# The loss at epoch  29  was  0.5428510904312134
# The loss at epoch  30  was  0.5437164306640625
# The loss at epoch  31  was  0.5425198078155518
# The loss at epoch  32  was  0.5430613160133362
# The loss at epoch  33  was  0.5423325896263123
# The loss at epoch  34  was  0.5430359244346619
# The loss at epoch  35  was  0.5420069098472595
# The loss at epoch  36  was  0.5424121618270874
# The loss at epoch  37  was  0.5417901277542114
# The loss at epoch  38  was  0.5426210165023804
# The loss at epoch  39  was  0.5417253971099854
# The loss at epoch  40  was  0.5423336029052734
# The loss at epoch  41  was  0.541631817817688
# The loss at epoch  42  was  0.542441725730896
# The loss at epoch  43  was  0.5413289070129395
# The loss at epoch  44  was  0.541782557964325
# The loss at epoch  45  was  0.541096568107605
# The loss at epoch  46  was  0.5419040322303772
# The loss at epoch  47  was  0.5409226417541504
# The loss at epoch  195  was  0.5161373019218445
# The loss at epoch  196  was  0.512657880783081
# The loss at epoch  197  was  0.512599527835846
# The loss at epoch  198  was  0.5141324996948242
# The loss at epoch  199  was  0.5149449706077576
# The loss at epoch  200  was  0.5141835808753967

# %%
from sklearn.manifold import TSNE, MDS

# %%
tsne = TSNE(n_components=2)
mds = MDS(n_components=2)

# %%
import sklearn.cluster as cluster

# %%
clf = cluster.KMeans(n_clusters=2)

# %%
all_embeddings = kernel_model.get_all_weights()

# %%
viable_embeddings = all_embeddings[1:,:]

# %%
reduced = tsne.fit_transform(viable_embeddings)

# %%
colors = ['blue' if x == 0 else 'red' for x in data.get_node_classes()]
from pylab import rcParams
rcParams['figure.figsize'] = 20, 20
rcParams['axes.titlesize'] = 14

# %%
plt.scatter(reduced[:,0], reduced[:,1],c=colors)

# %%
labels = clf.fit_predict(viable_embeddings)

# %%
labels
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int32)

# %%
correct_labels = data.get_node_classes()

# %%
len(correct_labels)
# Out:
# 1224

# %%
from sklearn.metrics.cluster import normalized_mutual_info_score

# %%
normalized_mutual_info_score(correct_labels, labels)
# Out:
# 0.0065553475535561311

# %%
num_nodes = data.get_num_nodes()
dims = 32
epochs = 100
lr = 0.1
lr_decay=0.0
weight_decay=0.0
lam = 0.00055
p = 2
delta = 1
delta0 = 0.5
dims_array = [dims, 20, 20]

# %%
model_fitter = models.fit_sine_model
triples, triples0 = util.triples_from_array(X, y)
batch_size = int(1.0 * len(triples))
batch_size0 = int(1.0 * len(triples0))

# %%
sine_model = model_fitter(num_nodes, dims_array, triples, triples0, delta, delta0,
                                   batch_size, batch_size0, epochs, lr=lr, lr_decay=lr_decay,
                                  lam=lam, p=p, p0=True)
# Out:
# Loss at epoch  1  is  0.9803027510643005
# Loss at epoch  2  is  0.8426938056945801
# Loss at epoch  3  is  0.42770424485206604
# Loss at epoch  4  is  0.8150202035903931
# Loss at epoch  5  is  0.40579289197921753
# Loss at epoch  6  is  0.4192911684513092
# Loss at epoch  7  is  0.4130207300186157
# Loss at epoch  8  is  0.3644466996192932
# Loss at epoch  9  is  0.3321684002876282
# Loss at epoch  10  is  0.2969439923763275
# Loss at epoch  11  is  0.28415849804878235
# Loss at epoch  12  is  0.3257910907268524
# Loss at epoch  13  is  0.3327062427997589
# Loss at epoch  14  is  0.24508345127105713
# Loss at epoch  15  is  0.2182871550321579
# Loss at epoch  16  is  0.21487250924110413
# Loss at epoch  17  is  0.21093377470970154
# Loss at epoch  18  is  0.20890259742736816
# Loss at epoch  19  is  0.20757083594799042
# Loss at epoch  20  is  0.20651672780513763
# Loss at epoch  21  is  0.20576468110084534
# Loss at epoch  22  is  0.20523974299430847
# Loss at epoch  23  is  0.20472007989883423
# Loss at epoch  24  is  0.20425789058208466
# Loss at epoch  25  is  0.2038733959197998
# Loss at epoch  26  is  0.2035178542137146
# Loss at epoch  27  is  0.2032969892024994
# Loss at epoch  28  is  0.20326422154903412
# Loss at epoch  29  is  0.2028471827507019
# Loss at epoch  30  is  0.20256832242012024
# Loss at epoch  31  is  0.20239531993865967
# Loss at epoch  32  is  0.20219165086746216
# Loss at epoch  33  is  0.2020368129014969
# Loss at epoch  34  is  0.2018377035856247
# Loss at epoch  35  is  0.20169630646705627
# Loss at epoch  36  is  0.20157676935195923
# Loss at epoch  37  is  0.20139122009277344
# Loss at epoch  38  is  0.20126140117645264
# Loss at epoch  39  is  0.20118995010852814
# Loss at epoch  40  is  0.20104104280471802
# Loss at epoch  41  is  0.2009480893611908
# Loss at epoch  42  is  0.2007770836353302
# Loss at epoch  43  is  0.20066767930984497
# Loss at epoch  44  is  0.20055842399597168
# Loss at epoch  45  is  0.20049059391021729
# Loss at epoch  46  is  0.20036670565605164
# Loss at epoch  47  is  0.20027689635753632
# Loss at epoch  48  is  0.20024272799491882
# Loss at epoch  49  is  0.2001332938671112
# Loss at epoch  50  is  0.20003171265125275
# Loss at epoch  51  is  0.19988371431827545
# Loss at epoch  52  is  0.19977080821990967
# Loss at epoch  53  is  0.19969381392002106
# Loss at epoch  54  is  0.19968952238559723
# Loss at epoch  55  is  0.19958677887916565
# Loss at epoch  56  is  0.19981452822685242
# Loss at epoch  57  is  0.19950968027114868
# Loss at epoch  58  is  0.1994367092847824
# Loss at epoch  59  is  0.19934239983558655
# Loss at epoch  60  is  0.1992289125919342
# Loss at epoch  61  is  0.19911739230155945
# Loss at epoch  62  is  0.19904133677482605
# Loss at epoch  63  is  0.19895115494728088
# Loss at epoch  64  is  0.1988973319530487
# Loss at epoch  65  is  0.19884145259857178
# Loss at epoch  66  is  0.1988021284341812
# Loss at epoch  67  is  0.19872932136058807
# Loss at epoch  68  is  0.19871585071086884
# Loss at epoch  69  is  0.19865790009498596
# Loss at epoch  70  is  0.19863641262054443
# Loss at epoch  71  is  0.19898058474063873
# Loss at epoch  72  is  0.19861376285552979
# Loss at epoch  73  is  0.19849134981632233
# Loss at epoch  74  is  0.19843168556690216
# Loss at epoch  75  is  0.19839689135551453
# Loss at epoch  76  is  0.19832080602645874
# Loss at epoch  77  is  0.19828678667545319
# Loss at epoch  78  is  0.19826506078243256
# Loss at epoch  79  is  0.1981976479291916
# Loss at epoch  80  is  0.19816944003105164
# Loss at epoch  81  is  0.1980949342250824
# Loss at epoch  82  is  0.19804517924785614
# Loss at epoch  83  is  0.19797807931900024
# Loss at epoch  84  is  0.1979248821735382
# Loss at epoch  85  is  0.1979081928730011
# Loss at epoch  86  is  0.19783645868301392
# Loss at epoch  87  is  0.1978253424167633
# Loss at epoch  88  is  0.1977788209915161
# Loss at epoch  89  is  0.19772911071777344
# Loss at epoch  90  is  0.19768604636192322
# Loss at epoch  91  is  0.19763270020484924
# Loss at epoch  92  is  0.19759511947631836
# Loss at epoch  93  is  0.19755347073078156
# Loss at epoch  94  is  0.19750414788722992
# Loss at epoch  95  is  0.19747544825077057
# Loss at epoch  96  is  0.19743318855762482
# Loss at epoch  97  is  0.19737741351127625
# Loss at epoch  98  is  0.19735869765281677
# Loss at epoch  99  is  0.19731619954109192
# Loss at epoch  100  is  0.1972881406545639

# %%
clf2 = cluster.KMeans(n_clusters=2)
all_embeddings2 = sine_model.get_all_weights()
viable_embeddings2 = all_embeddings2[1:,:]
labels2 = clf2.fit_predict(viable_embeddings2)

# %%
normalized_mutual_info_score(correct_labels, labels2)
# Out:
# 0.44151671486141431
